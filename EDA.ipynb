# %% [markdown]
# ## Домашнее задание 3 (10 баллов)
#
# ## НИУ ВШЭ, 2023-24 учебный год

# %% [markdown]
# ## О задании

# %% [markdown]
# В этом домашнем задании вы получите опыт подготовки данных и EDA (Exploratory Data Analysis), приблизившись к реальной работе с данными с помощью уже знакомых вам инструментов: numpy, pandas, matplotlib и seaborn, а также познакомитесь с plotly.
#
# EDA - важный этап работы с данными. Именно в процессе EDA вы можете выяснить особенности датасета, найти зависимости в данных, протестировать гипотезы о взаимосвязях признаков и целевой переменной. В реальности вы сами будете определять, что и как проверять в рамках EDA, однако в данной работе гипотезы будут выдвинуты за вас автором задания. Также и типы графиков, которые вы будете использовать уже предопределены за вас. Выполняя задания по визуализациям, обращайте внимание на референсные картинки, которые были оставлены автором. Они показывают, какой примерно результат от вас ожидается.
#
# Это задание будет включать в себя построение некоторого количества графиков, потому вот основные правила, в соответствии с которыми графики должны быть оформлены:
# 1. Любой график всегда имеет название.
# 2. Оси у графика подписаны (исключение - график делит название оси с соседним).
# 3. Подписи делаются на одном языке (либо английский, либо русский), но не на их смеси.
# 4. Если вы выводите несколько графиков, то они размещаются в рамках одного объекта matplotlib.pyplot.figure. Вы не выводите графики последовательно, а смотрите, как их разместить сразу все за раз.
# 5. Отдельные графики (если графиков на картинке больше 1) также имеют свои названия.
# 6. Если на графике есть несколько различных объектов, то для их различения используется легенда. Помещайте легенду в место, где она в наименьшей мере мешает восприятию самого графика.
# 7. Если есть легенда, то она должна иметь навание, а также ее содержание должно быть адекватными (пожалейте проверяющих, они не хотят разбирать, а к чему относится зеленая линия, которая на легенде помечена меткой "0").
# 8. Используйте цветовые гаммы, чтобы объекты на графиках отличались цветом.
# 9. Текст на визуализации должен быть читаем. Если вы вывели названия категорий в качестве подписей на оси Х, а эти названия наезжают друг на друга, то вам нужно что-то с этим сделать. Нечитаемый или плохо читаемый (очень маленький, невероятно огромный) текст ведет к снижению баллов.
#
# *Тут правило про плагиат, которое вам итак известно - обнуляются все работы, которые подозреваются в некорректных заимствованиях!* Помните, что просто скопировать код из интернета и указать источник - это не ваша самостоятельная работа, а автора кода. Измените хоть что-нибудь в коде.

# %% [markdown]
# ## О данных

# %% [markdown]
# Будем работать с [датасетом физической активности](https://www.kaggle.com/datasets/uciml/human-activity-recognition-with-smartphones).
#
# В этом датасете собраны данные 30 человек, выполняющих различные действия со смартфоном на поясе. Данные записывались с помощью датчиков (акселерометра и гироскопа) в этом смартфоне. Были зафиксированы: "3-осевое линейное ускорение" (_tAcc-XYZ_) и "3-осевая угловая скорость" (_tGyro-XYZ_).
#
# 1. Все сигналы отсортированы по времени, пропущены через фильтр шума.
# 2. Все наблюдения были разделены на окна по 128 сигналов в каждом, причем окна пересекаются на 50% (грубо говоря, с 1 по 128 сигнал в 1 окно, с 64 до 192 сигнала - во 2 окно и так далее).
# 3. Линейное ускорение было разделено на две составляющие (с помощью низкочастотного фильтра): ускорение самого тела, а также гравитационная составляющая. Будем называть их ускорением тела и гравитационным ускорением.
# 4. К получившимся окнам применяли различные функции для получения следующих показателей:
#     - max
#     - min
#     - mad (median)
#     - mean
#     - std
#     - skewness (коэффициент асимметричности распределения признака в окне)
#     - etc. (подробнее, на сколько это возможно, указано на [страничке датасета](https://archive.ics.uci.edu/dataset/240/human+activity+recognition+using+smartphones))
# 5. Величина (magnitude) сигнала также определялась через евклидову норму всех значений из вектора для одного окна.
# 6. К окнам было применено преобразование Фурье, чтобы получить частоты. Из частот были извелченыте же показатели, плюс новые:
#     - bandsEnergy (энергия частотного интервала)
# 7. Были посчитаны углы между векторами соответствующих окон.
# 8. Для ускорений были посчитаны производные - рывки, к которым применялись те же функции.
#
# Итог: в датасете каждый признак - это какая-то операция над вектором из 128 чисел, которые соответствуют замерам определенного человека занятого какой-то активностью на протяжении 2.56 секунд.
#
# Как читать названия признаков? Примеры:
# - `tBodyAccMag-mean()` - это вектор ускорений тела (без гравитационной составляющей этого ускорения), из которого взяли евклидову норму, а затем усреднили, чтобы получить скаляр
# - `fBodyAcc-bandsEnergy()-1,8.2` - это вектор ускорения тела, к которому применили преобразование Фурье, преобразовав его в вектор частот, а затем посчитали на этом векторе энергию данного частотного интервала в определенном диапазоне частот (в данном случае 1 - 8.2)
# - `angle(X,gravityMean)` - это угол между осью Х и вектором усредненных значений гравитационного ускорения из соответствующего окна
#
# Вероятно, сначала покажется сложным, но мы разберемся с некоторыми признаками в отдельности и вы сможете понять их смысл, уже исходя из фактических соотношений.

# %% [markdown]
# ## Предобработка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv("test.csv")

# %%
train.shape
# Out:
# (7352, 563)

# %% [markdown]
# В датасете 563 признака, включая целевую переменную. Столько признаков нам не нужно. Мы за вас сделали подвыборку признаков для удобства работы с ними.

# %%
cols_subset = [
    'tBodyAccMag-mean()',  # усредненная величина ускорения тела
    'tBodyGyroJerk-mad()-X',  # медианная величина рывка тела по оси Х
    'tGravityAcc-min()-X',  # минимум гравитационной составляющей ускорения по оси Х
    'tBodyAcc-max()-X',  # максимальная величина ускорения тела по оси Х
    'fBodyAcc-bandsEnergy()-1,8.2',  # энергия ускорения тела в интервале частоты
    'angle(X,gravityMean)',  # угол между осью Х и усредненной гравитационной составляющей ускорения
    'angle(Y,gravityMean)',  # угол между осью Y и усредненной гравитационной составляющей ускорения
    'angle(Z,gravityMean)',  # угол между осью Z и усредненной гравитационной составляющей ускорения,
    'fBodyAcc-skewness()-X',  # асимметричность частоты ускорения тела по оси Х
    'subject',  # номер испытуемого
    'Activity',  # название вида деятельности (целевая переменная)
]

# %%
train = train[cols_subset]
test = test[cols_subset]

# %% [markdown]
# ### Задание 1 (0.5 балла)
#
# Посмотрите на пропуски и дубли в данных train и test. Есть ли они? Если есть, напишите, с чем это может быть связано? Если нет, то просто напишите, что пропусков и/или дублей нет.

# %%
print('Пропуски в данных train есть.' if train.isna().any().any() else 'Пропусков в данных train нет.')
print('Пропуски в данных test есть.' if test.isna().any().any() else 'Пропусков в данных test нет.')
print('Дубликаты в данных train есть.' if train.duplicated().any() else 'Дубликатов в данных train нет.')
print('Дубликаты в данных test есть.' if train.duplicated().any() else 'Дубликатов в данных test нет.')
# Out:
# Пропусков в данных train нет.
# Пропусков в данных test нет.
# Дубликатов в данных train нет.
# Дубликатов в данных test нет.

# %% [markdown]
# ### Задание 2 (0.5 балла)
#
# Выведите основные статистики данных: среднее, медиана, перцентили (0.25, 0.5, 0.75), минимум, максимум, стандартное отклонение. Посмотрите на таблицу и напишите, видите ли вы в ней что-нибудь интересное.

# %%
train.describe()
# Out:
#        tBodyAccMag-mean()  tBodyGyroJerk-mad()-X  tGravityAcc-min()-X  \
# count         7352.000000            7352.000000          7352.000000
# mean            -0.543884              -0.727735             0.678505
# std              0.477653               0.315832             0.508656
# min             -1.000000              -0.999889            -1.000000
# 25%             -0.983282              -0.991595             0.804270
# 50%             -0.883371              -0.950268             0.926693
# 75%             -0.106892              -0.474625             0.965095
# max              1.000000               1.000000             1.000000
#
#        tBodyAcc-max()-X  fBodyAcc-bandsEnergy()-1,8.2  angle(X,gravityMean)  \
# count       7352.000000                   7352.000000           7352.000000
# mean          -0.468604                     -0.847963             -0.489547
# std            0.544547                      0.233633              0.511807
# min           -1.000000                     -1.000000             -1.000000
# 25%           -0.936219                     -0.999480             -0.812065
# 50%           -0.881637                     -0.986582             -0.709417
# 75%           -0.017129                     -0.764508             -0.509079
# max            1.000000                      1.000000              1.000000
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)  fBodyAcc-skewness()-X  \
# count           7352.000000           7352.000000            7352.000000
# mean               0.058593             -0.056515              -0.128562
# std                0.297480              0.279122               0.403686
# min               -1.000000             -1.000000              -0.931208
# 25%               -0.017885             -0.143414              -0.486841
# 50%                0.182071              0.003181              -0.163271
# 75%                0.248353              0.107659               0.155112
# max                0.478157              1.000000               1.000000
#
#            subject
# count  7352.000000
# mean     17.413085
# std       8.975143
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000

# %% [markdown]
# 1. Большинство признаков имеют значения от -1 до 1.
# 2. Выделяется среднее значение fBodyAcc-bandsEnergy()-1,8.2, т.к. оно наиболее приближенное к границам этого интервала среди всех остальных.
# 3. 75% значений fBodyAcc-skewness()-X меньше 0.155112 при максимальном значении = 1, возможно, выбросы
# 4. В основном данные отклоняются от среднего значения на 0.4-0.5.

# %%
test.describe()
# Out:
#        tBodyAccMag-mean()  tBodyGyroJerk-mad()-X  tGravityAcc-min()-X  \
# count         2947.000000            2947.000000          2947.000000
# mean            -0.559043              -0.735661             0.696878
# std              0.439539               0.282074             0.502873
# min             -0.998936              -1.000000            -0.756774
# 25%             -0.978433              -0.989078             0.836787
# 50%             -0.861830              -0.914698             0.934930
# 75%             -0.149596              -0.486423             0.970871
# max              0.479547               0.117606             0.996148
#
#        tBodyAcc-max()-X  fBodyAcc-bandsEnergy()-1,8.2  angle(X,gravityMean)  \
# count       2947.000000                   2947.000000           2947.000000
# mean          -0.462063                     -0.880361             -0.513923
# std            0.523916                      0.160496              0.509205
# min           -0.952357                     -0.999989             -0.984195
# 25%           -0.934447                     -0.999330             -0.829722
# 50%           -0.852659                     -0.979336             -0.729648
# 75%           -0.009965                     -0.799113             -0.545939
# max            0.786436                      0.048730              0.833180
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)  fBodyAcc-skewness()-X  \
# count           2947.000000           2947.000000            2947.000000
# mean               0.074886             -0.048720              -0.154042
# std                0.324300              0.241467               0.392203
# min               -0.913704             -0.949228              -1.000000
# 25%                0.022140             -0.098485              -0.497070
# 50%                0.181563             -0.010671              -0.202050
# 75%                0.260252              0.092373               0.140254
# max                1.000000              0.973113               0.960367
#
#            subject
# count  2947.000000
# mean     12.986427
# std       6.950984
# min       2.000000
# 25%       9.000000
# 50%      12.000000
# 75%      18.000000
# max      24.000000

# %% [markdown]
# 1. В отличие от train, признаки имеют разброс значений в минимальных и максимальных. Например, tBodyGyroJerk-mad()-X принимает значения от -1 до 0.117606, а не от -1 до 1 как в train.
# 2. Средние значения практически не отличаются от значений из предыдущей выборки.
# 3. 75% значений tBodyAcc-max()-X меньше -0.009965 при максимальном значении = 0.786436, возможно, выбросы
# 4. В основном данные отклоняются от среднего значения на 0.4-0.5.

# %% [markdown]
# ### Задание 3 (0.5 балла)
#
# Данные сбалансированы? У вас есть 6 категорий активности (целевая переменная). Если одна из категорий представлена большим количеством наблюдений, а остальные - нет, то это обстоятельство, о котором хотелось бы знать заранее. Гиперболизированный пример: представьте, что у вас 1000 наблюдений, разделенных на два класса, и только 5 принадлежат ко второму классу. Как учить модель на такой выборке? Есть сильное подозрение, что многие модели будут склонны вырождаться в константу. Отсюда и необходимость проверять баланс классов.
#
# Выведите количество наблюдений для всех категорий активности в train и test. Посчитайте разницу в процентах между самой крупной категорией и самой маленькой (самая большая категория - это 100%). Если разница (округленная до ближайшего целого числа) не превышает 30%, то давайте для наших целей считать, что данные сбалансированы. Напишите, сбалансированы ли данные в train и test.

# %%
display(train['Activity'].value_counts())

max_count = max(train['Activity'].value_counts())
# print(max_count)
min_count = min(train['Activity'].value_counts())
# print(min_count)

difference = round((max_count - min_count) * 100 / max_count)
if difference <= 30:
  print(f'Данные train сбалансированы! Разница в процентах между самой крупной категорией и самой маленькой = {difference}%, что не превышает 30% ')
else:
  print(f'Данные train несбалансированны :(  Разница в процентах между самой крупной категорией и самой маленькой = {difference}%, что больше 30%')
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64
# Данные train сбалансированы! Разница в процентах между самой крупной категорией и самой маленькой = 30%, что не превышает 30%

# %%
display(test['Activity'].value_counts())

max_count = max(test['Activity'].value_counts())
# print(max_count)
min_count = min(test['Activity'].value_counts())
# print(min_count)

difference = round((max_count - min_count) * 100 / max_count)
if difference <= 30:
  print(f'Данные test сбалансированы! Разница в процентах между самой крупной категорией и самой маленькой = {difference}%, что не превышает 30% ')
else:
  print(f'Данные test несбалансированны :(  Разница в процентах между самой крупной категорией и самой маленькой = {difference}%, что больше 30%')
# Out:
# LAYING                537
# STANDING              532
# WALKING               496
# SITTING               491
# WALKING_UPSTAIRS      471
# WALKING_DOWNSTAIRS    420
# Name: Activity, dtype: int64
# Данные test сбалансированы! Разница в процентах между самой крупной категорией и самой маленькой = 22%, что не превышает 30%

# %% [markdown]
# ### Задание 4 (0.5 балла)
#
# Посчитайте корреляции всех признаков (включая таргет) со всеми другими. Какими получились значения? Есть идеи, почему так? Напишите ваши мысли.

# %%
train.corr()
# Out:
#                               tBodyAccMag-mean()  tBodyGyroJerk-mad()-X  \
# tBodyAccMag-mean()                      1.000000               0.899080
# tBodyGyroJerk-mad()-X                   0.899080               1.000000
# tGravityAcc-min()-X                     0.369962               0.380118
# tBodyAcc-max()-X                        0.959827               0.879900
# fBodyAcc-bandsEnergy()-1,8.2            0.697832               0.507939
# angle(X,gravityMean)                   -0.370849              -0.382246
# angle(Y,gravityMean)                    0.495561               0.478567
# angle(Z,gravityMean)                    0.426283               0.380967
# fBodyAcc-skewness()-X                   0.379796               0.266002
# subject                                -0.073652              -0.110321
#
#                               tGravityAcc-min()-X  tBodyAcc-max()-X  \
# tBodyAccMag-mean()                       0.369962          0.959827
# tBodyGyroJerk-mad()-X                    0.380118          0.879900
# tGravityAcc-min()-X                      1.000000          0.380404
# tBodyAcc-max()-X                         0.380404          1.000000
# fBodyAcc-bandsEnergy()-1,8.2             0.239088          0.613383
# angle(X,gravityMean)                    -0.988663         -0.384192
# angle(Y,gravityMean)                     0.797116          0.480229
# angle(Z,gravityMean)                     0.667415          0.405023
# fBodyAcc-skewness()-X                   -0.261676          0.335708
# subject                                 -0.042371         -0.055633
#
#                               fBodyAcc-bandsEnergy()-1,8.2  \
# tBodyAccMag-mean()                                0.697832
# tBodyGyroJerk-mad()-X                             0.507939
# tGravityAcc-min()-X                               0.239088
# tBodyAcc-max()-X                                  0.613383
# fBodyAcc-bandsEnergy()-1,8.2                      1.000000
# angle(X,gravityMean)                             -0.213318
# angle(Y,gravityMean)                              0.363170
# angle(Z,gravityMean)                              0.423927
# fBodyAcc-skewness()-X                             0.260316
# subject                                          -0.037000
#
#                               angle(X,gravityMean)  angle(Y,gravityMean)  \
# tBodyAccMag-mean()                       -0.370849              0.495561
# tBodyGyroJerk-mad()-X                    -0.382246              0.478567
# tGravityAcc-min()-X                      -0.988663              0.797116
# tBodyAcc-max()-X                         -0.384192              0.480229
# fBodyAcc-bandsEnergy()-1,8.2             -0.213318              0.363170
# angle(X,gravityMean)                      1.000000             -0.783848
# angle(Y,gravityMean)                     -0.783848              1.000000
# angle(Z,gravityMean)                     -0.643655              0.594885
# fBodyAcc-skewness()-X                     0.265523             -0.046213
# subject                                   0.026137             -0.009829
#
#                               angle(Z,gravityMean)  fBodyAcc-skewness()-X  \
# tBodyAccMag-mean()                        0.426283               0.379796
# tBodyGyroJerk-mad()-X                     0.380967               0.266002
# tGravityAcc-min()-X                       0.667415              -0.261676
# tBodyAcc-max()-X                          0.405023               0.335708
# fBodyAcc-bandsEnergy()-1,8.2              0.423927               0.260316
# angle(X,gravityMean)                     -0.643655               0.265523
# angle(Y,gravityMean)                      0.594885              -0.046213
# angle(Z,gravityMean)                      1.000000              -0.183815
# fBodyAcc-skewness()-X                    -0.183815               1.000000
# subject                                  -0.098712               0.019742
#
#                                subject
# tBodyAccMag-mean()           -0.073652
# tBodyGyroJerk-mad()-X        -0.110321
# tGravityAcc-min()-X          -0.042371
# tBodyAcc-max()-X             -0.055633
# fBodyAcc-bandsEnergy()-1,8.2 -0.037000
# angle(X,gravityMean)          0.026137
# angle(Y,gravityMean)         -0.009829
# angle(Z,gravityMean)         -0.098712
# fBodyAcc-skewness()-X         0.019742
# subject                       1.000000

# %% [markdown]
# Значения корреляции получились как положительными, так и отрицательными, т.е. между переменными есть не только прямая, но и обратная связь. Заметно, что большинство значений крутятся в пределах 0.5 по модулю.
#
# Вектор ускорений тела tBodyAccMag-mean() и максимальная величина ускорения тела по оси Х tBodyAcc-max()-X обладают наибольшей корреляцией (0.959827), что подтверждает существующую между ними сильную прямую зависимость.
#
# Минимум гравитационной составляющей ускорения по оси Х tGravityAcc-min()-X и угол между осью X и усредненной гравитационной составляющей ускорения angle(X,gravityMean) имеют значимую обратную связь (-0.988663).
#
# Таргет наименее зависим от других признаков.

# %%
test.corr()
# Out:
#                               tBodyAccMag-mean()  tBodyGyroJerk-mad()-X  \
# tBodyAccMag-mean()                      1.000000               0.934773
# tBodyGyroJerk-mad()-X                   0.934773               1.000000
# tGravityAcc-min()-X                     0.407084               0.393773
# tBodyAcc-max()-X                        0.965114               0.898628
# fBodyAcc-bandsEnergy()-1,8.2            0.767875               0.625414
# angle(X,gravityMean)                   -0.400871              -0.387274
# angle(Y,gravityMean)                    0.439051               0.423288
# angle(Z,gravityMean)                    0.425011               0.368411
# fBodyAcc-skewness()-X                   0.365670               0.278765
# subject                                -0.057359              -0.079811
#
#                               tGravityAcc-min()-X  tBodyAcc-max()-X  \
# tBodyAccMag-mean()                       0.407084          0.965114
# tBodyGyroJerk-mad()-X                    0.393773          0.898628
# tGravityAcc-min()-X                      1.000000          0.386764
# tBodyAcc-max()-X                         0.386764          1.000000
# fBodyAcc-bandsEnergy()-1,8.2             0.301643          0.707129
# angle(X,gravityMean)                    -0.989043         -0.384454
# angle(Y,gravityMean)                     0.697006          0.410477
# angle(Z,gravityMean)                     0.633881          0.398008
# fBodyAcc-skewness()-X                   -0.237864          0.338543
# subject                                  0.004927         -0.071786
#
#                               fBodyAcc-bandsEnergy()-1,8.2  \
# tBodyAccMag-mean()                                0.767875
# tBodyGyroJerk-mad()-X                             0.625414
# tGravityAcc-min()-X                               0.301643
# tBodyAcc-max()-X                                  0.707129
# fBodyAcc-bandsEnergy()-1,8.2                      1.000000
# angle(X,gravityMean)                             -0.279783
# angle(Y,gravityMean)                              0.327473
# angle(Z,gravityMean)                              0.446245
# fBodyAcc-skewness()-X                             0.293881
# subject                                          -0.090817
#
#                               angle(X,gravityMean)  angle(Y,gravityMean)  \
# tBodyAccMag-mean()                       -0.400871              0.439051
# tBodyGyroJerk-mad()-X                    -0.387274              0.423288
# tGravityAcc-min()-X                      -0.989043              0.697006
# tBodyAcc-max()-X                         -0.384454              0.410477
# fBodyAcc-bandsEnergy()-1,8.2             -0.279783              0.327473
# angle(X,gravityMean)                      1.000000             -0.668108
# angle(Y,gravityMean)                     -0.668108              1.000000
# angle(Z,gravityMean)                     -0.615114              0.425454
# fBodyAcc-skewness()-X                     0.235208             -0.087006
# subject                                   0.003138             -0.047553
#
#                               angle(Z,gravityMean)  fBodyAcc-skewness()-X  \
# tBodyAccMag-mean()                        0.425011               0.365670
# tBodyGyroJerk-mad()-X                     0.368411               0.278765
# tGravityAcc-min()-X                       0.633881              -0.237864
# tBodyAcc-max()-X                          0.398008               0.338543
# fBodyAcc-bandsEnergy()-1,8.2              0.446245               0.293881
# angle(X,gravityMean)                     -0.615114               0.235208
# angle(Y,gravityMean)                      0.425454              -0.087006
# angle(Z,gravityMean)                      1.000000              -0.208121
# fBodyAcc-skewness()-X                    -0.208121               1.000000
# subject                                   0.055885               0.015103
#
#                                subject
# tBodyAccMag-mean()           -0.057359
# tBodyGyroJerk-mad()-X        -0.079811
# tGravityAcc-min()-X           0.004927
# tBodyAcc-max()-X             -0.071786
# fBodyAcc-bandsEnergy()-1,8.2 -0.090817
# angle(X,gravityMean)          0.003138
# angle(Y,gravityMean)         -0.047553
# angle(Z,gravityMean)          0.055885
# fBodyAcc-skewness()-X         0.015103
# subject                       1.000000

# %% [markdown]
# Значения корреляции получились как положительными, так и отрицательными, т.е. между переменными есть не только прямая, но и обратная связь. Заметно, что большинство значений крутятся в пределах 0.5 по модулю.
#
# Медианная величина рывка тела по оси Х tBodyGyroJerk-mad()-X и усредненная величина ускорения тела tBodyAccMag-mean() обладают наибольшей корреляцией (0.934773), что подтверждает существующую между ними сильную прямую зависимость.
#
# Минимум гравитационной составляющей ускорения по оси Х tGravityAcc-min()-X и угол между осью X и усредненной гравитационной составляющей ускоренияangle(X,gravityMean) имеют значимую обратную связь (-0.989043).
#
# Таргет наименее зависим от других признаков.

# %% [markdown]
# Полученнные значения для обеих таблиц близки. Однако в тестовой выборке  корреляции по модулю немного больше.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import math

# %% [markdown]
# ### Задание 5 (0.5 балла)
#
# Вы проверили основную информацию о данных и составили свое первое впечатление о них. Теперь визуализации.
#
# Начнем рисовать графики с небольшой разминки. Выберите две любые математические функции (отличные от линейной) и нарисуйте их на одном графике. Подпишите каждый из графиков, чтобы было понятно, какие функции вы выбрали. Ниже будет пример.

# %%
x = list(range(-2, 3))
y1 = [math.sqrt(1 - (abs(x1)-1)**2) for x1 in x]
y2 = [-2.5 * math.sqrt(1 - math.sqrt(abs(x)/2)) for x in x]
# рисуем графики
plt.plot(x, y1, label='y = (1-(|x|-1)^2)^0.5', color='red')
plt.plot(x, y2, label='y = -2.5*(1-(|x|/2)^0.5)^0.5', color='blue')
# добавляем название
plt.title('My functions', fontweight='bold')
# подписывем оси
plt.xlabel('X')
plt.ylabel('Y')
# делаем сетку как в примере
plt.grid()
# задаем легенду
plt.legend(title='Legend', fontsize='x-small', loc='lower left')
# выводим на экран
plt.show()

# %% [markdown]
# ### Задание 6 (0.5 балла)
#
# Ранее мы уже проверили сбалансированность данных по разным категориям активностей в train и test сетах. Теперь визуализируйте количество сэмплов в каждой из категорий отдельно для train и test сетов, как в примере ниже. Проследите, чтобы порядок категорий слева и справа был одинаков. Иначе не очень удобно их сравнивать (когда они в разных местах двух графиков). Также заметьте, что в примере ось Х в одинаковом масштабе, что тоже удобно для сравнения.
#
# Вам может пригодиться:
# - plt.barh или ax.barh

# %%
# создаем объект figure
fig, ax = plt.subplots(1, 2, figsize=(15, 5), dpi=300, layout='tight')
# указываем общий заголовок
fig.suptitle('Target variables distribution', size='x-large', fontweight='bold')
# данные для построения
train_X = train['Activity'].value_counts().index
train_Y = train['Activity'].value_counts().values
test_X = test['Activity'].value_counts().index
test_Y = test['Activity'].value_counts().values

ax[0].set_title('Train set') # указываем индивидуальный заголовок
ax[0].barh(train_X, train_Y, color = 'green') # визуализируем количество сэмплов
ax[0].set_xlabel('Number of samples')
ax[0].set_ylabel('Activities')
ax[0].set_xlim(0, 1500) # делаем ось Х в одинаковом масштабе
ax[0].invert_xaxis() # отзеркаливаем график

ax[1].set_title('Test set') # указываем индивидуальный заголовок
ax[1].set_xlim(0, 1500) # делаем ось Х в одинаковом масштабе
ax[1].barh(train_X, test_Y, color = 'red') # визуализируем количество сэмплов
ax[1].yaxis.set_ticks_position('right')
ax[1].set_xlabel('Number of samples')

plt.subplots_adjust(left=0, right=1)
plt.show()

# %% [markdown]
# Правда на таких графиках проще проверять баланс классов таргета?) - Правда!

# %% [markdown]
# ### Задание 7 (0.5 балла)
#
# Ранее вы выводили таблицу корреляций. Однако просто таблица корреляций не очень удобна для анализа. Что, если признаков было бы больше? Визуализируйте heatmap корреляций. Подпишите значения корреляций, округленные до 2 знаков после запятой, на графике и оставьте только те значения, которые по модулю не меньше 0.5. Будем считать такие корреляции существенными. Если будете брать код из семинарского ноутбука, то поменяйте в нем что-нибудь, например, цветовую гамму, иначе проверяющий будет карать :)
#
# Какой признак стоит исключить из рассмотрения корреляций? Напишите его название, а также причину, почему нет смысла его рассматривать.
#
# Вам может пригодиться:
# - sns.heatmap
# - методы get_text и set_text у атрибута texts графика

# %%
NumericData = train[cols_subset]
colormap = plt.cm.BuPu # новая цветовая гамма
plt.figure(figsize=(9, 10))
plt.title('Correlation heatmap (train)', size='xx-large', fontweight='bold')
ax = sns.heatmap(
    round(NumericData.corr(), 2), # значения корреляций, округленные до 2 знаков после запятой
    linewidths=0.1,
    vmax=1.0,
    square=True,
    cmap=colormap,
    linecolor="white",
    annot=True,
    fmt='.2g' # формат значений корреляций, округленных до 2 знаков после запятой
)
# оставляем только те значения, которые по модулю не меньше 0.5
for t in ax.texts:
    if abs(float(t.get_text())) >= 0.5:
        t.set_text(t.get_text())
    else:
        t.set_text("")

# %%
NumericData = test[cols_subset]
colormap = plt.cm.BuPu # новая цветовая гамма
plt.figure(figsize=(9, 10))
plt.title('Correlation heatmap (test)', size='xx-large', fontweight='bold')
ax = sns.heatmap(
    round(NumericData.corr(), 2), # значения корреляций, округленные до 2 знаков после запятой
    linewidths=0.1,
    vmax=1.0,
    square=True,
    cmap=colormap,
    linecolor="white",
    annot=True,
    fmt='.2g' # формат значений корреляций, округленных до 2 знаков после запятой
)
# оставляем только те значения, которые по модулю не меньше 0.5
for t in ax.texts:
    if abs(float(t.get_text())) >= 0.5:
        t.set_text(t.get_text())
    else:
        t.set_text("")

# %% [markdown]
# Признак асимметричность частоты ускорения тела по оси Х fBodyAcc-skewness()-X стоит исключить из рассмотрения корреляций, т.к. для него значения корреляций со всеми другими признаками меньше 0.5 - несущественные, поэтому нет смысла его рассматривать.

# %% [markdown]
# ### Задание 8 (0.5 балла)
#
# Для начала будем стрелять из пушки по воробьям. Выведите pairplot по всем данным train сета. Напишите, заметили ли вы в нем что-нибудь интересное, чего не было в таблицах и графиках ранее, а также сообщите, было ли вам удобно анализировать 100 графиков.

# %%
sns.pairplot(
    train,
    size=4,
    diag_kind='hist'
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Выделяется распределение минимума гравитационной составляющей ускорения по оси Х и углов между осями и ним, точки группируются достаточно необычно от -1 до 0 более-менее равномерно, а от 0.5 до 1 "э"-образно. В принципе минимум гравитационной составляющей ускорения по оси Х в половине представленных графиков скапливается вблизи границ левого верхнего угла.
#
# Еще интересно посмотреть на распределение таргета, по оси Х в районе 10 наблюдается менее плотное распределение, по оси Y заметны пропуски в интервале  от -0.5 до 0.25.
#
# А вообще рссматривать 100 графиков очень неудобно(

# %% [markdown]
# ### Задание 9 (1 балл)
#
# Окей. Смотреть на все сразу не очень удобно. Кажется, нужно смотреть на признаки в отдельности и искать в них инсайты.
#
# Попробуем проверить гипотезу. Отобразите плотность распределения (kde) `tBodyAccMag-mean()` для каждой из активностей, как в примере ниже. Видите закономерность? Можно ли поделить все активности на две группы? Если да, то проведите вертикальную линию, которая визуально неплохо разделяет эти группы.
#
# Давайте первую группу называть статическими активностями, а вторую - динамическими.
#
# Посчитайте, какую долю правильных ответов дает ваша вертикальная линия для разделения именно этих двух групп. С чем может быть связан полученный вами результат? Предположите логическое обоснование (почему именно данный признак так хорошо/плохо разделяет группы активностей).
#
# Вам может пригодиться:
# - sns.kdeplot

# %%
plt.title('Mean body acceleration for activities', fontsize = 'large', fontweight='bold') # указываем заголовок
plt.xlabel('Body acceleration', fontsize = 'small') # подписывем оси
plt.ylabel('Density', fontsize = 'small')

# построим графики плотности распределений для каждой из активностей
sns.kdeplot(data = train, x = train['tBodyAccMag-mean()'], hue=train['Activity'], palette='bright')
# проведем вертикальную линию, которая визуально разделяет 2 группы
plt.axvline(-0.6, color='black');

plt.show()

# %% [markdown]
# Можно заметить закономерность, что для активностей, связанных с ходьбой, усредненная величина ускорения тела tBodyAccMag-mean() "кучкуется" около -1.0, а для активностей, связанных с более статичными упражнениями, - около 0.
# Поэтому мы можем поделить эти активности на две группы. Проведем вертикальную линию x=-0.6, которая визуально разделит эти группы.

# %%
dinamic_predict = train[train['tBodyAccMag-mean()'] >= -0.6]
static_predict = train[train['tBodyAccMag-mean()'] < -0.6]

print(f"Правильная доля для динамичных = {len(dinamic_predict[(dinamic_predict['Activity'] != 'STANDING') & (dinamic_predict['Activity'] != 'SITTING') & (dinamic_predict['Activity'] != 'LAYING')]) / len(train[(train['Activity'] != 'STANDING') & (train['Activity'] != 'SITTING') & (train['Activity'] != 'LAYING')])}")
print(f"Правильная доля для статичных = {len(static_predict[(static_predict['Activity'] != 'WALKING') & (static_predict['Activity'] != 'WALKING_UPSTAIRS') & (static_predict['Activity'] != 'WALKING_DOWNSTAIRS')]) / len(train[(train['Activity'] != 'WALKING') & (train['Activity'] != 'WALKING_UPSTAIRS') & (train['Activity'] != 'WALKING_DOWNSTAIRS')]):.2f}")
# Out:
# Правильная доля для динамичных = 1.0
# Правильная доля для статичных = 0.98

# %% [markdown]
# Полученный результат может быть связан с тем, что статичные упражнения могут вызывать небольшое замедление тела, поэтому усредненная величина ускорения тела tBodyAccMag-mean() отрицательная. А динамичные упражнения требуют как ускорения, так и замедления, поэтому разброс значения от -0.5 до 0.5 приводит к нулевому среднему. Именно поэтому данный признак так хорошо разделяет активности на две группы.

# %% [markdown]
# ### Задание 10 (0.5 балла)
#
# Поздравляем, вы проверили первую гипотезу в процессе EDA. Однако нам бы хотелось уметь не группы разделять, а каждый отдельный вид активности. Попробуйте нарисовать "ящики с усами" для `angle(X,gravityMean)` с разделением по разным видам активности на данных train. Можно ли сделать какой-то вывод по полученной визуализации? Проанализируйте и проинтерпретируйте полученные картинки (если заметили какую-то особенность, может какая-то категория значительно выделяется, то предположите, почему так могло произойти).
#
# Вам может пригодиться:
# - sns.boxplot

# %%
fig, ax = plt.subplots(figsize=(15, 5), layout='tight')
sns.axes_style('white')
ax.set_title('Angle between X-axis and gravitatioanal acceleration', fontsize = 'large', fontweight='bold') # указываем заголовок
ax.set_xlabel('Activity', fontsize = 'small') # подписывем оси
ax.set_ylabel('Angle', fontsize = 'small')
# выводим на экран
sns.boxplot(train[['angle(X,gravityMean)','Activity']], x=train['Activity'], y=train['angle(X,gravityMean)'], hue=train['Activity'], palette='bright')
# Out:
# <Axes: title={'center': 'Angle between X-axis and gravitatioanal acceleration'}, xlabel='Activity', ylabel='Angle'>

# %% [markdown]
# Категория LAYING выделяется относительно всех остальных, находясь выше, принимая значения от 0.25. Возможно, это происходит из-за того, что для данной активности угол между осью X и гравитационной составляющей ускорения имеет большее значение.
#
# Полученная визуализация поможет в дальнейшем для отделения LAYING от других видов активностей.

# %% [markdown]
# ### Задание 11 (0.5 балла)
#
# Посмотрим теперь на `tBodyAcc-max()-X`. Визуализируйте скрипичные диаграммы для этого признака с разделением по активностям на всем train. Кажется логичным, что максимальное ускорение в моменте для разных активностей будет различаться. Однако есть ли активность, которая будет выделяться? Если да, то предложите объяснение, почему эта активность выделяется.
#
# Вам может пригодиться:
# - sns.violinplot

# %%
fig, ax = plt.subplots(figsize=(15, 5), layout='tight')
sns.axes_style('white')
ax.set_title('Maximal body acceleration over activities', fontsize = 'large', fontweight='bold') # указываем заголовок
ax.set_xlabel('Activity', fontsize = 'small') # подписывем оси
ax.set_ylabel('Maximal acceleration', fontsize = 'small')
# выводим на экран
sns.violinplot(train[['tBodyAcc-max()-X','Activity']], x=train['Activity'], y=train['tBodyAcc-max()-X'], hue=train['Activity'], palette='bright', split=True, inner='quart', linewidth=1)
# Out:
# <Axes: title={'center': 'Maximal body acceleration over activities'}, xlabel='Activity', ylabel='Maximal acceleration'>

# %% [markdown]
# Выделяется активность WALKING_DOWNSTAIRS, медианное и среднее значения максимального ускорения которой наблюдается в районе 0.5, что выше всех остальных активностей. Это логично, т.к. спуск характеризуется более высоким ускорением, чем просто ходьба или подъем, это легче физически.

# %% [markdown]
# ### Задание 12 (1 балл)
#
# Вы уже можете с довольно хорошим качеством выделить две категории активности из шести. Продолжим.
#
# Ранее уже упоминалось разделение на две группы активностей: статические и динамические. Пришла пора разделить датасет train на две части. Сделайте это! Теперь на одной картинке покажите распределения `fBodyAcc-bandsEnergy()-1,8.2` для динамичных активностей (boxenplot - немного измененый "ящик с усами") и `angle(Y,gravityMean)` для статических - тут хватит и простой гистограммы (прямо, как в примере ниже). Можно ли выделить еще какие-то активности? Если да, напишите, какие активности на 1 и 2 графиках выделяются.
#
# Вам может пригодиться:
# - plt.subplots или matplotlib.gridspec (заметили, что один график больше другого? попробуйте сами так сделать - вам понравится...)
# - sns.boxenplot
# - sns.histplot

# %%
# создаем объект figure
fig, ax = plt.subplots(1, 2, figsize=(15, 5), dpi=300, layout='tight', gridspec_kw = {'width_ratios': (.65, .45)})
# указываем общий заголовок
fig.suptitle('Angle and Energy for activity groups', size='x-large', fontweight='bold')
# данные для построения
dinamic_train = train[(train['Activity'] != 'STANDING') & (train['Activity'] != 'SITTING') & (train['Activity'] != 'LAYING')]
static_train = train[(train['Activity'] != 'WALKING') & (train['Activity'] != 'WALKING_UPSTAIRS') & (train['Activity'] != 'WALKING_DOWNSTAIRS')]

ax[0].set_title('Dinamic activities') # указываем индивидуальный заголовок
sns.boxenplot(data = dinamic_train, y = dinamic_train['fBodyAcc-bandsEnergy()-1,8.2'], x = dinamic_train['Activity'], palette='bright', orient='v', ax = ax[0]) # визуализируем
ax[0].set_xlabel('Activity', fontsize = 'small')
ax[0].set_ylabel('Frequency energy', fontsize = 'small')

ax[1].set_title('Static activities') # указываем индивидуальный заголовок
sns.histplot(data = static_train, x = static_train['angle(Y,gravityMean)'], hue = static_train['Activity'], palette='bright', ax = ax[1], bins=50) # визуализируем
ax[1].set_xlabel('Angle', fontsize = 'small')
ax[1].set_ylabel('Count', fontsize = 'small')

plt.show()

# %% [markdown]
# На 1 графике можно выделить активность WALKING_UPSTAIRS, показывающую наибольший разброс в значениях энергия ускорения тела в интервале частоты fBodyAcc-bandsEnergy()-1,8.2 и имеющую значения выше 0.3 (в отличие от других динамических активностей).
#
# На 2 графике хорошо выделяется STANDING, его можно легко выделить в значениях  угла между осью Y и усредненной гравитационной составляющей ускорения angle(Y,gravityMean) от 0 до 0.3.

# %% [markdown]
# ### Задание 13 (0.5 балла)
#
# Не всегда жизнь будет такой легкой, а данные будут полностью или почти линейно разделимы в одному признаку (иначе чем бы занимались дата саентисты...). Часто данные вообще ни по одному признаку нельзя адекватно разделить (да и по комбинациям признаков тоже). Давайте попробуем взять не один признак, а целых два!
#
# Рассмотрим только статические активности. Будет снова два графика сразу. На первом графике будет боксплот распределения `fBodyAcc-skewness()-X` по активностям. А на втором попробуем взять не все наблюдения данной группы активностей, а только их часть. Разделимы ли категории по `fBodyAcc-skewness()-X`? А если взять только те строки, где `fBodyAcc-skewness()-X < -0.376`, и теперь вывести боксплот распределения `angle(Y,gravityMean)` по разным активностям? Попробуйте и напишите, выделилась ли какая-то категория?
#
# Вам может пригодиться:
# - plt.subplots или matplotlib.gridspec
# - sns.boxplot

# %%
# создаем объект figure
fig, ax = plt.subplots(1, 2, figsize=(15, 5), layout='tight', dpi=300)
# указываем общий заголовок
fig.suptitle('Acceleration and Angle over static activities', size='x-large', fontweight='bold')
# данные для построения
static_train = train[(train['Activity'] != 'WALKING') & (train['Activity'] != 'WALKING_UPSTAIRS') & (train['Activity'] != 'WALKING_DOWNSTAIRS')]

ax[0].set_title('Skewness of body acceleration over activities') # указываем индивидуальный заголовок
sns.boxplot(data = static_train, y = static_train['fBodyAcc-skewness()-X'], x = static_train['Activity'], palette='bright', ax = ax[0]) # визуализируем
ax[0].set_xlabel('Activity', fontsize = 'small')
ax[0].set_ylabel('Skewness', fontsize = 'small')

ax[1].set_title('Angle between Y-axis and gravity acceleration over activities') # указываем индивидуальный заголовок
sns.boxplot(data = static_train, y = static_train['angle(Y,gravityMean)'][train['fBodyAcc-skewness()-X'] < -0.376], x = static_train['Activity'], palette='bright', ax = ax[1]) # визуализируем
ax[1].set_xlabel('Angle', fontsize = 'small')
ax[1].set_ylabel('Activity', fontsize = 'small')

plt.show()

# %% [markdown]
# Категории по fBodyAcc-skewness()-X разделимы, для 2 графика можем взять только те строки, где fBodyAcc-skewness()-X < -0.376, и вывести боксплот распределения angle(Y,gravityMean) по разным активностям.
# По 1 графику не выделить ничего особо, а вот 2 график показывает еще не выделяемую до этого категорию SITTING, у которой все средние значения симметричности частоты ускорения тела по оси Х от 0.1 до -0.1.

# %% [markdown]
# ### Задание 14 (1 балл)
#
# Вот и осталась лишь одна активность, которую мы никак не выделили. Попробуем и ее какими-то порогами отделить от всех остальных. Да, можно было бы сказать, что, раз уж мы выделили 5 из 6 категорий, то все остальное - это и есть последняя категория, но мы не идем легкими путями. Выделить оставшуюсь категорию с хорошим качеством не так уж и просто. Из доступных признаков, сначала посмотрите на распределение `tBodyAcc-max()-X` на динамических активностях (скрипичная диаграмма отлично подойдет).
#
# А теперь спускаем вам порог `tBodyAcc-max()-X < 0.157`. Для таких строк постройте диаграмму рассеяния для признака `tGravityAcc-min()-X`. Да, получается неидеально, но это честная работа. Можно выбрать порог так, чтобы чисто из таблицы с динамическими активностями из строк, где `tBodyAcc-max()-X < 0.157`, выбрать по некоторому порогу для `tGravityAcc-min()-X` строки так, чтобы доля правильных ответов на оставшейся категории была не меньше 83%!
#
# Вам может пригодиться:
# - plt.subplots или matplotlib.gridspec
# - sns.violinplot
# - sns.swarmplot (иногда лучше подходит, чем просто sns.scatterplot)
#
# Обратите внимание, что подписи к осям можно убирать методами plt. Например, если у вас общее название для оси Y для обоих графиков, то можно не подписывать ось Y у второго графика.

# %%
# создаем объект figure
fig, ax = plt.subplots(1, 2, figsize=(15, 5), layout='tight', dpi=300)
# указываем общий заголовок
fig.suptitle('Body and gravity acceleration over dinamic activities', size='x-large', fontweight='bold')
# данные для построения
dinamic_train = train[(train['Activity'] != 'STANDING') & (train['Activity'] != 'SITTING') & (train['Activity'] != 'LAYING')]

ax[0].set_title('Maximal body acceleration over activities') # указываем индивидуальный заголовок
sns.violinplot(data = dinamic_train, y = dinamic_train['tBodyAcc-max()-X'], x = dinamic_train['Activity'], palette='bright', ax = ax[0]) # визуализируем
ax[0].set_xlabel('Activity', fontsize = 'small')
ax[0].set_ylabel('Acceleration', fontsize = 'small')

ax[1].set_title('Minimal gravity acceleration over activities') # указываем индивидуальный заголовок
sns.swarmplot(data = dinamic_train, y = dinamic_train['tGravityAcc-min()-X'][train['tBodyAcc-max()-X'] < 0.157], x = dinamic_train['Activity'], palette='bright', ax = ax[1]) # визуализируем
ax[1].set_xlabel('Activity', fontsize = 'small')
ax[1].set_ylabel('')
plt.show()

# %% [markdown]
# Получается, что мы можем выделить категорию WALKING на значениях с максимальной величиной ускорения тела по оси ХtBodyAcc-max()-X меньшей 0.157, где минимум гравитационной составляющей ускорения по оси Х tGravityAcc-min()-X равен или больше 0.95.
#
# Кроме того, если минимум гравитационной составляющей ускорения по оси Х tGravityAcc-min()-X меньше 0.85 при максимальной величиной ускорения тела по оси ХtBodyAcc-max()-X меньшей 0.157, то можно выделить WALKING_UPSTAIRS.

# %% [markdown]
# ### Задание 15 (0.5 балла)
#
# Теперь попробуем более интерактивные графики. Установите библиотеку `plotly` (обычно `pip install plotly` или `conda install plotly`). Синтаксис очень похож на `seaborn`, но вот [документация для plotly.express](https://plotly.com/python-api-reference/plotly.express.html).
#
# Сначала подготовим данные для визуализации. Будем считать t-SNE просто "черным ящиком", который принимает наши данные и проецирует их в двумерное или трехмерное пространство. Возможно, придется немного подождать.

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %%
# %%time
from sklearn.manifold import TSNE
tsne = TSNE(random_state=666, n_components=2)
new = tsne.fit_transform(train.drop(['subject', 'Activity'], axis=1))
df_2_comp = pd.concat([
    pd.DataFrame(new, columns=['x', 'y']),
    train['Activity']
], axis=1)

tsne = TSNE(random_state=666, n_components=3)
new = tsne.fit_transform(train.drop(['subject', 'Activity'], axis=1))
df_3_comp = pd.concat([
    pd.DataFrame(new, columns=['x', 'y', 'z']),
    train['Activity']
], axis=1)
# Out:
# CPU times: user 6min 27s, sys: 531 ms, total: 6min 28s
# Wall time: 4min 27s

# %% [markdown]
# Теперь нарисуйте scatter-график через `plotly.express` для `df_2_comp` с выделением цветами активностей. Красиво получилось? Видны скопления точек одного цвета? Можно разные активности отделить линиями на данном графике?

# %%
import plotly.express as px
fig = px.scatter(df_2_comp, x='x', y='y', color='Activity', hover_data='Activity', title='Activity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="427ab7f0-73ec-4c73-87ca-6c6696ecc0c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("427ab7f0-73ec-4c73-87ca-6c6696ecc0c2")) {                    Plotly.newPlot(                        "427ab7f0-73ec-4c73-87ca-6c6696ecc0c2",                        [{"customdata":[["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],[" ...

# %% [markdown]
# Видны скопления точек одного цвета, при желании их можно отделить линиями друг от друга, но выбросы все равно попадают в "чужие" области.

# %% [markdown]
# Мы не отстаем от трендов и тоже можем в 3D. Сейчас и вы научитесь (если еще не умеете). Нарисуйте scatter_3d-график через `plotly.express` для `df_3_comp` с выделением цветами активностей. Повращайте его. Нормально получилось? Есть ли какая-то структура у точек?

# %%
fig = px.scatter_3d(df_3_comp, x='x', y='y', z='z', color='Activity', hover_data='Activity', title='Activity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9774920d-605a-448c-886c-11d36db41129" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9774920d-605a-448c-886c-11d36db41129")) {                    Plotly.newPlot(                        "9774920d-605a-448c-886c-11d36db41129",                        [{"customdata":[["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],["STANDING"],[" ...

# %% [markdown]
# Точки расположены шарообразно, LAYING кучкуется слегка в отдалении от других, STANDING и SITTING частично перемешались. Оставшиеся 3 показателя также расположены близко друг к другу.

# %% [markdown]
# ### Задание 16 (1 балл)
#
# Мы сделали вам fit. Ваша очередь сделать predict. Допишите функцию, которая принимает на вход датафрейм с признаками, а выдает вектор из предсказаний - для каждой строки датафрейма вы определяете, к какому классу принадлежит объект. Рекомендуем сразу записывать из строками, а не кодировать в числа. Дальше фукнция `accuracy_score` выдаст вам долю правильных ответов.
#
# Подсказка: вы уже отделили категории друг от друга по каким-то признакам. Воспользуйтесь этим знанием! Используя только проведенный вами анализ можно спокойно выбить не менее 75% на train и test! Если вы получите меньше 75%, то балл будет снижен. Авторское решение (на основе всех графиков выше) выбивает 81% и 77% на train и test соответственно. [Шапргалка с готовыми идеями для такой задачи](https://www.youtube.com/watch?v=dQw4w9WgXcQ)

# %%
def predict(df: pd.DataFrame):
  df['Predict']  = np.vectorize(lambda x, y, z, a, b, c, d: ('WALKING_DOWNSTAIRS' if y > 0.3 else ('WALKING_UPSTAIRS' if z > 0 else ('WALKING' if (((y < 0.157) and (c > 0.95)) or y < -0.25) else 'WALKING_UPSTAIRS')) ) if x >= -0.6 else ('LAYING' if a > 0.2 else ('STANDING' if 0.15 <= b <= 0.3 else ('SITTING' if ((d < -0.376) and (b<0)) else ('STANDING' if (d < -0.376) and (b > 0.95) else 'SITTING')))))(df['tBodyAccMag-mean()'], df['tBodyAcc-max()-X'], df['fBodyAcc-bandsEnergy()-1,8.2'], df['angle(X,gravityMean)'], df['angle(Y,gravityMean)'], df['tGravityAcc-min()-X'], df['fBodyAcc-skewness()-X'])
  return df['Predict']

def accuracy_score(y_true, y_pred) -> float:
    y_true = np.asarray(y_true).reshape(-1, 1)
    y_pred = np.asarray(y_pred).reshape(-1, 1)
    return (y_true == y_pred).mean()

# %%
train_preds = predict(train)
test_preds = predict(test)
print(f"Accuracy on train set => {accuracy_score(train['Activity'], train_preds)}")
print(f"Accuracy on test set => {accuracy_score(test['Activity'], test_preds)}")
# Out:
# Accuracy on train set => 0.8181447225244831
# Accuracy on test set => 0.7611129962673906
